# %%
import torch
# %load_ext autoreload
# %autoreload 2
from transformers import AutoTokenizer, AutoModelForSequenceClassification
from TestingSuite import ModelsTestingSuite
from TestedModel import *
from Training.utlis import train_test_split_data
import pandas as pd
import joblib

# %% [markdown]
# ### Loading Data

# %%
df = pd.read_pickle("../data/combined_df.pkl")
df["content_text_joined"] = df["content_words"].apply(lambda x: " ".join(x))
TEXT_COL = "content_text_joined"    
LABEL_COL = "is_spoiler"      

# Split
_, X, _, y = train_test_split_data(
    df,
    TEXT_COL,
    LABEL_COL
)

# %%
X.shape
# Out:
# (30000,)

# %%
batch_nr=30

# %% [markdown]
# ### Initializing testing suite

# %%
suite=ModelsTestingSuite(X=X.to_numpy(),y=y.to_numpy())

# %%
tfidf_svm=joblib.load("../models/svm_tfidf.pkl")
bow_logreg=joblib.load("../models/logreg_bow.pkl")

# %%
suite.add(ClassicalModel(model=tfidf_svm,name="tfidf_svm"))
suite.add(ClassicalModel(model=bow_logreg,name="bow_logreg"))

# %%
bert_path="../Models/BERTa/final_model"
bert_tokenizer = AutoTokenizer.from_pretrained(bert_path)
bert_model = AutoModelForSequenceClassification.from_pretrained(bert_path)

# %%
suite.add(BertModel(model=bert_model,tokenizer=bert_tokenizer,name="bert"))

# %%
roberta_path="../Models/RoBERTa/final_model"
roberta_model=AutoModelForSequenceClassification.from_pretrained(roberta_path)
roberta_tokenizer = AutoTokenizer.from_pretrained(roberta_path)

# %%
suite.add(BertModel(model=roberta_model,tokenizer=roberta_tokenizer,name="roberta"))

# %% [markdown]
# ## Evaluating metrics

# %%
acc_results=suite.evaluate(metric="accuracy",batch_nr=batch_nr)
# Out:
# Batch 1/30 finished
# Batch 2/30 finished
# Batch 3/30 finished
# Batch 4/30 finished
# Batch 5/30 finished
# Batch 6/30 finished
# Batch 7/30 finished
# Batch 8/30 finished
# Batch 9/30 finished
# Batch 10/30 finished
# Batch 11/30 finished
# Batch 12/30 finished
# Batch 13/30 finished
# Batch 14/30 finished
# Batch 15/30 finished
# Batch 16/30 finished
# Batch 17/30 finished
# Batch 18/30 finished
# Batch 19/30 finished
# Batch 20/30 finished
# Batch 21/30 finished
# Batch 22/30 finished
# Batch 23/30 finished
# Batch 24/30 finished
# Batch 25/30 finished
# Batch 26/30 finished
# Batch 27/30 finished
# Batch 28/30 finished
# Batch 29/30 finished
# Batch 30/30 finished

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %%
df=pd.DataFrame.from_dict(acc_results)
df1=df.melt().rename(columns={"value":"Accuracy","variable":"Model"})
plot=sns.boxplot(x="Model",y="Accuracy",data=df1).set_title("Accuracy comparison")
fig=plot.get_figure()
fig.savefig("figs/Accuracy_comparison.png")

# %%
f1_results=suite.evaluate(metric="f1_score",batch_nr=batch_nr)
# Out:
# Batch 1/30 finished
# Batch 2/30 finished
# Batch 3/30 finished
# Batch 4/30 finished
# Batch 5/30 finished
# Batch 6/30 finished
# Batch 7/30 finished
# Batch 8/30 finished
# Batch 9/30 finished
# Batch 10/30 finished
# Batch 11/30 finished
# Batch 12/30 finished
# Batch 13/30 finished
# Batch 14/30 finished
# Batch 15/30 finished
# Batch 16/30 finished
# Batch 17/30 finished
# Batch 18/30 finished
# Batch 19/30 finished
# Batch 20/30 finished
# Batch 21/30 finished
# Batch 22/30 finished
# Batch 23/30 finished
# Batch 24/30 finished
# Batch 25/30 finished
# Batch 26/30 finished
# Batch 27/30 finished
# Batch 28/30 finished
# Batch 29/30 finished
# Batch 30/30 finished

# %%
df=pd.DataFrame.from_dict(f1_results)
df1=df.melt().rename(columns={"value":"f1_score","variable":"Model"})
plot=sns.boxplot(x="Model",y="f1_score",data=df1).set_title("f1 score comparison")
fig=plot.get_figure()
fig.savefig("figs/f1_results_comparison.png")

# %%
mcc_results=suite.evaluate(metric="mcc",batch_nr=batch_nr)
# Out:
# Batch 1/30 finished
# Batch 2/30 finished
# Batch 3/30 finished
# Batch 4/30 finished
# Batch 5/30 finished
# Batch 6/30 finished
# Batch 7/30 finished
# Batch 8/30 finished
# Batch 9/30 finished
# Batch 10/30 finished
# Batch 11/30 finished
# Batch 12/30 finished
# Batch 13/30 finished
# Batch 14/30 finished
# Batch 15/30 finished
# Batch 16/30 finished
# Batch 17/30 finished
# Batch 18/30 finished
# Batch 19/30 finished
# Batch 20/30 finished
# Batch 21/30 finished
# Batch 22/30 finished
# Batch 23/30 finished
# Batch 24/30 finished
# Batch 25/30 finished
# Batch 26/30 finished
# Batch 27/30 finished
# Batch 28/30 finished
# Batch 29/30 finished
# Batch 30/30 finished

# %%
df=pd.DataFrame.from_dict(mcc_results)
df1=df.melt().rename(columns={"value":"mcc","variable":"Model"})
plot=sns.boxplot(x="Model",y="mcc",data=df1).set_title("mcc comparison")
fig=plot.get_figure()
fig.savefig("figs/mcc_results_comparison.png")

# %% [markdown]
# ### Inference time tests

# %%
time_results=suite.measure_time(batch_nr=60)
# Out:
# Batch 1/60 finished
# Batch 2/60 finished
# Batch 3/60 finished
# Batch 4/60 finished
# Batch 5/60 finished
# Batch 6/60 finished
# Batch 7/60 finished
# Batch 8/60 finished
# Batch 9/60 finished
# Batch 10/60 finished
# Batch 11/60 finished
# Batch 12/60 finished
# Batch 13/60 finished
# Batch 14/60 finished
# Batch 15/60 finished
# Batch 16/60 finished
# Batch 17/60 finished
# Batch 18/60 finished
# Batch 19/60 finished
# Batch 20/60 finished
# Batch 21/60 finished
# Batch 22/60 finished
# Batch 23/60 finished
# Batch 24/60 finished
# Batch 25/60 finished
# Batch 26/60 finished
# Batch 27/60 finished
# Batch 28/60 finished
# Batch 29/60 finished
# Batch 30/60 finished
# Batch 31/60 finished
# Batch 32/60 finished
# Batch 33/60 finished
# Batch 34/60 finished
# Batch 35/60 finished
# Batch 36/60 finished
# Batch 37/60 finished
# Batch 38/60 finished
# Batch 39/60 finished
# Batch 40/60 finished
# Batch 41/60 finished
# Batch 42/60 finished
# Batch 43/60 finished
# Batch 44/60 finished
# Batch 45/60 finished
# Batch 46/60 finished
# Batch 47/60 finished
# Batch 48/60 finished
# Batch 49/60 finished
# Batch 50/60 finished
# Batch 51/60 finished
# Batch 52/60 finished
# Batch 53/60 finished
# Batch 54/60 finished
# Batch 55/60 finished
# Batch 56/60 finished
# Batch 57/60 finished
# Batch 58/60 finished
# Batch 59/60 finished
# Batch 60/60 finished

# %%
dft=pd.DataFrame.from_dict(time_results)
dft1=dft.melt().rename(columns={"value":"time [s]","variable":"Model"})
sns.boxplot(x="Model",y="time [s]",data=dft1).set_title(f"inference time comparison for 10 records per batch")
fig=plot.get_figure()
fig.savefig("figs/time_results_comparison_10_pb.png")

# %%
# Out:
# C:\Users\18pep\AppData\Local\Temp\ipykernel_33428\463783792.py:1: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
