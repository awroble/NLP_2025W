# %%
import pandas as pd
import ast

from ollama import chat
from ollama import ChatResponse
all_results = {}
df = pd.read_csv('nlp(cultural_pictures).csv', sep=';',encoding ='utf-8')
df["correct_answers"] = df["correct_answers"].apply(ast.literal_eval)
df["country"] = df["country"].apply(ast.literal_eval)

#df["correct_answers_2"] = df["correct_answers_2"].apply(ast.literal_eval)
df
# Out:
#     id                                               link  \
# 0    1  https://upload.wikimedia.org/wikipedia/commons...
# 1    2  https://upload.wikimedia.org/wikipedia/commons...
# 2    3  https://upload.wikimedia.org/wikipedia/commons...
# 3    4  https://commons.wikimedia.org/wiki/Category:Al...
# 4    5  https://commons.wikimedia.org/wiki/Category:Av...
# 5    6  https://upload.wikimedia.org/wikipedia/commons...
# 6    7  https://upload.wikimedia.org/wikipedia/commons...
# 7    8  https://upload.wikimedia.org/wikipedia/commons...
# 8    9  https://upload.wikimedia.org/wikipedia/commons...
# 9   10  https://upload.wikimedia.org/wikipedia/commons...
# 10  11  https://upload.wikimedia.org/wikipedia/commons...
# 11  12  https://upload.wikimedia.org/wikipedia/commons...
# 12  13  https://upload.wikimedia.org/wikipedia/commons...
# 13  14  https://upload.wikimedia.org/wikipedia/commons...
# 14  15  https://upload.wikimedia.org/wikipedia/commons...
# 15  16  https://upload.wikimedia.org/wikipedia/commons...
# 16  17  https://upload.wikimedia.org/wikipedia/commons...
# 17  18  https://upload.wikimedia.org/wikipedia/commons...
# 18  19  https://upload.wikimedia.org/wikipedia/commons...
# 19  20  https://upload.wikimedia.org/wikipedia/commons...
# 20  21  https://upload.wikimedia.org/wikipedia/commons...
# 21  22  https://upload.wikimedia.org/wikipedia/commons...
# 22  23  https://commons.wikimedia.org/wiki/File:Nelson...
# 23  24  https://upload.wikimedia.org/wikipedia/commons...
# 24  25  https://commons.wikimedia.org/wiki/File:Hatra_...
# 25  26  https://upload.wikimedia.org/wikipedia/commons...
# 26  27  https://en.wikipedia.org/wiki/Notre-Dame_de_Pa...
# 27  28  https://upload.wikimedia.org/wikipedia/commons...
# 28  29  https://upload.wikimedia.org/wikipedia/commons...
# 29  30  https://upload.wikimedia.org/wikipedia/commons...
# 30  31  https://upload.wikimedia.org/wikipedia/commons...
# 31  32  https://upload.wikimedia.org/wikipedia/commons...
# 32  33  https://upload.wikimedia.org/wikipedia/commons...
# 33  34  https://upload.wikimedia.org/wikipedia/commons...
# 34  35  https://upload.wikimedia.org/wikipedia/commons...
# 35  36  https://upload.wikimedia.org/wikipedia/commons...
# 36  37  https://upload.wikimedia.org/wikipedia/commons...
# 37  38  https://upload.wikimedia.org/wikipedia/commons...
# 38  39  https://commons.wikimedia.org/wiki/File:Old_Fi...
# 39  40  https://commons.wikimedia.org/wiki/File:Alg%C3...
#
#                                              question      type subcategory  \
# 0   With what culture/nation/national minority you...    direct      attire
# 1   With culture connected to what mountains attir...    direct      attire
# 2   With what particular historical event is this ...    direct     history
# 3   In honor of which historical figure was this b...  indirect     history
# 4           In what city is this building located in?    direct     culture
# 5   What is the name of this traditional dish of o...    direct        food
# 6          What is the name of this traditional dish?    direct        food
# 7   What is the name of this traditional Nigerian ...    direct        food
# 8   What is the name of the land/country/people be...    direct     culture
# 9   What is the name of God(s) represented on the ...    direct    religion
# 10  What is the name of figure represented by this...    direct    religion
# 11  What is the country which traditional dance is...    direct     culture
# 12  In what country does this building is being pl...  indirect     culture
# 13  In what country does this building is being pl...  indirect     culture
# 14  With what country usually such dish is connect...  indirect        food
# 15  What is the name of this traditional music ins...    direct     culture
# 16  What is the ethnic group to which presented mo...  indirect     culture
# 17  What is the name of the God represented by thi...    direct    religion
# 18  With what country is this picture connected with?    direct    religion
# 19  What is the name of this traditional attire pr...    direct     culture
# 20  What is the contest name, by winning which you...    direct     culture
# 21            In what town does this building stands?  indirect     culture
# 22  To what country is the person from the picture...  indirect     history
# 23                 What is the name of this building?    direct     history
# 24                 What is the name of this building?    direct     history
# 25            In what town does this building stands?  indirect     culture
# 26              In what year did this photo was made?  indirect     culture
# 27  What is the name of the architectonic element ...    direct     culture
# 28                 What is the name of this building?    direct     culture
# 29            In what town does this building stands?  indirect     culture
# 30         What is the name of this traditional cake?    direct        food
# 31      From what country does this person come from?  indirect     culture
# 32      From what country does this person come from?  indirect     culture
# 33      From what country does this person come from?  indirect     history
# 34  What is the name of the person represented by ...    direct     history
# 35       What drink is being presented on the picture    direct     culture
# 36                  What is the name of this bevarage    direct     culture
# 37  From what country does the game presented on t...  indirect     culture
# 38  From what country comes the game presented on ...  indirect     culture
# 39  From what country comes the game presented on ...  indirect     culture
#
#                                       country  \
# 0                                     [Spain]
# 1   [Colombia, Ecuador, Peru, Chile, Bolivia]
# 2                                   [Ukraine]
# 3                                  [Bulgaria]
# 4                                    [Sweden]
# 5                                    [Poland]
# 6                                   [Marocco]
# 7                                   [Nigeria]
# 8                                    [Yoruba]
# 9                                   [Nigeria]
# 10                                    [Japan]
# 11                                   [Greece]
# 12                                   [Mexico]
# 13                                   [Mexico]
# 14                   [Great Britain, England]
# 15                                [Australia]
# 16                                [Australia]
# 17                                    [Egypt]
# 18                                    [Egypt]
# 19                                    [Japan]
# 20                                   [Europe]
# 21                                      [USA]
# 22                             [South Africa]
# 23                                     [Oman]
# 24                                     [Iraq]
# 25                                   [Russia]
# 26                                   [France]
# 27                                   [Greece]
# 28                                    [Italy]
# 29                                    [Spain]
# 30                                 [Portugal]
# 31                                [Argentina]
# 32                                  [Germany]
# 33                                    [Spain]
# 34                                   [Turkey]
# 35     [Argentina, Paraguay, Uruguay, Brazil]
# 36                                    [China]
# 37                                    [India]
# 38                   [Great Britain, England]
# 39                   [Great Britain, England]
#
#                        correct_answers  correct_answers_2
# 0                          [Catalonia]                NaN
# 1                              [Andes]                NaN
# 2                  [Orange Revolution]                NaN
# 3   [Tsar Alexander II,  Alexander II]                NaN
# 4                          [Stockholm]                NaN
# 5                            [pierogi]                NaN
# 6               [Briouatbriwa, briwat]                NaN
# 7                             [frejon]                NaN
# 8                             [Yoruba]                NaN
# 9     [Ibeji, Ibejí, Ibeyí, Jimaguas ]                NaN
# 10                            [Buddha]                NaN
# 11                            [Greece]                NaN
# 12                            [Mexico]                NaN
# 13                            [Mexico]                NaN
# 14            [Great Britain, England]                NaN
# 15                        [Didgeridoo]                NaN
# 16                        [Aborigines]                NaN
# 17                         [Nefretiti]                NaN
# 18                             [Egypt]                NaN
# 19                             [Japan]                NaN
# 20                        [Eurovision]                NaN
# 21                       [Los Angeles]                NaN
# 22                      [South Africa]                NaN
# 23                        [Bahla Fort]                NaN
# 24                             [Hatra]                NaN
# 25                            [Moscow]                NaN
# 26                              [2019]                NaN
# 27                          [Caryatid]                NaN
# 28                         [Colosseum]                NaN
# 29                         [Barcelona]                NaN
# 30   [Pastéis de Nata, Pastel de nata]                NaN
# 31                         [Argentina]                NaN
# 32                           [Germany]                NaN
# 33                             [Spain]                NaN
# 34                  [Atatürk, Ataturk]                NaN
# 35                              [mate]                NaN
# 36                            [Baijiu]                NaN
# 37                             [India]                NaN
# 38            [Great Britain, England]                NaN
# 39            [Great Britain, England]                NaN

# %%
with open("pics/1.jpg", "rb") as f:
    image_bytes = f.read()

print("Rozmiar obrazu (bytes):", len(image_bytes))
print("Pierwsze bajty:", image_bytes[:10])
# Out:
# Rozmiar obrazu (bytes): 103840
# Pierwsze bajty: b'\xff\xd8\xff\xe0\x00\x10JFIF'

# %%
from ollama import chat
from ollama import ChatResponse

with open('pics/1.jpg', 'rb') as f:
    image_bytes = f.read()

response: ChatResponse = chat(
    model='qwen3-vl:2b',
    messages=[
        {
            'role': 'user',
            'content': df.iloc[0,2],
            'images': [image_bytes],
        }
    ]
)

print(response.message.content)
# Out:
# The photo most closely connects to the **Tatar culture** (specifically the Tatar ethnic group). Key indicators include:
# - The distinctive **red hats and red sashes**, which are hallmarks of traditional Tatar attire (particularly in the Volga region).
# - The white shirts and dark trousers, which align with common Tatar folk dress elements.
# - The group’s dynamic, celebratory posture, and the rural, natural setting (with willow trees and a wooden fence), which reflect the cultural and social context of Tatar communities.
#
# While the Tatars are part of the broader Turkic ethnic group, their unique cultural identity (rooted in the Volga region) is best evidenced by these visual markers in the photo.

# %%
import pandas as pd
import time
import os

from ollama import chat

def generate_response_ollama(prompt, image_path, model, temperature=0.1):
    with open(image_path, "rb") as f:
        image_bytes = f.read()
    print(prompt)
    response = chat(
        model=model,
        messages=[{
            "role": "user",
            "content": prompt,
            "images": [image_bytes]
        }],
        options={
            "temperature": temperature
        }
    )

    return response.message.content or ""


def check_answer(response, expected_answers):
    if not response or not expected_answers:
        return False
 
    response_lower = response.lower()

    return any(
        expected.lower() in response_lower
        for expected in expected_answers
    )
def find_image(image_dir, i):
    for ext in ("jpg", "png"):
        path = os.path.join(image_dir, f"{i}.{ext}")
        if os.path.exists(path):
            return path
    return None

def test_vision(
    models_to_test,
    prompts,
    image_dir,
    answers,
    answers2=None
):
    results = pd.DataFrame(index=range(len(prompts)), columns=models_to_test)
    result_prompts = pd.DataFrame(index=range(len(prompts)), columns=models_to_test)

    for model_name in models_to_test:
        print(f"\n{'='*60}")
        print(f"Testowanie modelu: {model_name}")
        print(f"{'='*60}")

        for i, prompt in enumerate(prompts, start=1):
            image_path = find_image(image_dir, i)
            if image_path is None:
                print(f"⚠ Brak obrazu dla indeksu {i} (jpg/png)")
                continue
            print(f"\nPrompt {i}/{len(prompts)} | Image: {image_path}")
            response = generate_response_ollama(
                prompt=prompt,
                image_path=image_path,
                model=model_name
            )
            result_prompts.loc[i-1, model_name] = response

            correct = check_answer(response, answers[i-1])
            

            results.loc[i-1, model_name] = correct
            print(f"Wynik: {'✓' if correct else '✗'}")
        result_prompts.to_csv(
            f"{model_name[:4]}_prompts_results.csv",
            encoding='utf-8-sig',
            index=False
)

        results.to_csv(
            f"{model_name[:4]}_results.csv",
            encoding='utf-8-sig',
            index=False
)
    # Podsumowanie
    print(f"\n{'='*60}")
    print("PODSUMOWANIE")
    print(f"{'='*60}")

    for model_name in models_to_test:
        correct_count = results[model_name].sum()
        total = len(results)
        accuracy = (correct_count / total * 100) if total > 0 else 0
        print(f"{model_name}: {accuracy:.1f}% ({correct_count}/{total})")

    return results, result_prompts

# %%
models = [
    "qwen3-vl:2b",
    "llama3.2-vision:11b"
]

results, responses = test_vision(
    models_to_test=models,
    prompts=df["question"].tolist(),
    image_dir="pics",
    answers=df['correct_answers'],
    answers2=df['correct_answers_2'])
# Out:
# ============================================================
# Testowanie modelu: qwen3-vl:2b
# ============================================================
#
# Prompt 1/40 | Image: pics\1.jpg
# With what culture/nation/national minority you connect the photo with
# Wynik: ✗
#
# Prompt 2/40 | Image: pics\2.jpg
# With culture connected to what mountains attire of this man is connected to
# Wynik: ✓
#
# Prompt 3/40 | Image: pics\3.jpg
# With what particular historical event is this photo connected with
# Wynik: ✗
#
# Prompt 4/40 | Image: pics\4.jpg
# In honor of which historical figure was this builfing built?
# Wynik: ✗
#
# Prompt 5/40 | Image: pics\5.jpg
# In what city is this building located in?
# Wynik: ✗
#
# Prompt 6/40 | Image: pics\6.jpg
# What is the name of this traditional dish of one of the central-european countries?
# Wynik: ✗
#
# Prompt 7/40 | Image: pics\7.jpg
# What is the name of this traditional dish?
# Wynik: ✗
#
# Prompt 8/40 | Image: pics\8.png
# What is the name of this traditional Nigerian soup?
# Wynik: ✗
#
# Prompt 9/40 | Image: pics\9.png
# What is the name of the land/country/people being represented with this flag?
# Wynik: ✗
#
# Prompt 10/40 | Image: pics\10.jpg
# What is the name of God(s) represented on the picture?
# Wynik: ✗
#
# Prompt 11/40 | Image: pics\11.jpg
# What is the name of figure represented by this monument?
# Wynik: ✓
#
# Prompt 12/40 | Image: pics\12.jpg
# What is the country which traditional dance is represented on the picture
# Wynik: ✗
#
# Prompt 13/40 | Image: pics\13.jpg
# In what country does this building is being placed?
# Wynik: ✗
#
# Prompt 14/40 | Image: pics\14.jpg
# In what country does this building is being placed?
# Wynik: ✓
#
# Prompt 15/40 | Image: pics\15.jpg
# With what country usually such dish is connected with?
# Wynik: ✗
#
# Prompt 16/40 | Image: pics\16.jpg
# What is the name of this traditional music instrument?
# Wynik: ✓
#
# Prompt 17/40 | Image: pics\17.jpg
# What is the ethnic group to which presented mountain is a holy place
# Wynik: ✗
#
# Prompt 18/40 | Image: pics\18.jpg
# What is the name of the God represented by this bust?
# Wynik: ✗
#
# Prompt 19/40 | Image: pics\19.jpg
# With what country is this picture connected with?
# Wynik: ✓
#
# Prompt 20/40 | Image: pics\20.jpg
# What is the name of this traditional attire presented on the picture?
# Wynik: ✓
#
# Prompt 21/40 | Image: pics\21.jpg
# What is the contest name, by winning which you receive the trophy from the picture?
# Wynik: ✓
#
# Prompt 22/40 | Image: pics\22.jpg
# In what town does this building stands?
# Wynik: ✗
#
# Prompt 23/40 | Image: pics\23.jpg
# To what country is the person from the picture important?
# Wynik: ✓
#
# Prompt 24/40 | Image: pics\24.jpg
# What is the name of this building?
# Wynik: ✗
#
# Prompt 25/40 | Image: pics\25.jpg
# What is the name of this building?
# Wynik: ✗
#
# Prompt 26/40 | Image: pics\26.jpg
# In what town does this building stands?
# Wynik: ✗
#
# Prompt 27/40 | Image: pics\27.jpg
# In what year did this photo was made?
# Wynik: ✓
#
# Prompt 28/40 | Image: pics\28.jpg
# What is the name of the architectonic element presented on the picture
# Wynik: ✗
#
# Prompt 29/40 | Image: pics\29.jpg
# What is the name of this building?
# Wynik: ✓
#
# Prompt 30/40 | Image: pics\30.jpg
# In what town does this building stands?
# Wynik: ✓
#
# Prompt 31/40 | Image: pics\31.jpg
# What is the name of this traditional cake?
# Wynik: ✓
#
# Prompt 32/40 | Image: pics\32.jpg
# From what country does this person come from?
# Wynik: ✓
#
# Prompt 33/40 | Image: pics\33.jpg
# From what country does this person come from?
# Wynik: ✓
#
# Prompt 34/40 | Image: pics\34.jpg
# From what country does this person come from?
# Wynik: ✓
#
# Prompt 35/40 | Image: pics\35.jpg
# What is the name of the person represented by this monument
# Wynik: ✓
#
# Prompt 36/40 | Image: pics\36.jpg
# What drink is being presented on the picture
# Wynik: ✓
#
# Prompt 37/40 | Image: pics\37.jpg
# What is the name of this bevarage
# Wynik: ✗
#
# Prompt 38/40 | Image: pics\38.jpg
# From what country does the game presented on the picture comes from?
# Wynik: ✗
#
# Prompt 39/40 | Image: pics\39.jpg
# From what country comes the game presented on the picture
# Wynik: ✗
#
# Prompt 40/40 | Image: pics\40.jpg
# From what country comes the game presented on the picture
# Wynik: ✗
#
# ============================================================
# Testowanie modelu: llama3.2-vision:11b
# ============================================================
#
# Prompt 1/40 | Image: pics\1.jpg
# With what culture/nation/national minority you connect the photo with
# ---------------------------------------------------------------------------
# ResponseError                             Traceback (most recent call last)
# Cell In[6], line 6
#       1 models = [
#       2     "qwen3-vl:2b",
#       3     "llama3.2-vision:11b"
#       4 ]
# ----> 6 results, responses = test_vision(
#       7     models_to_test=models,
#       8     prompts=df["question"].tolist(),
#       9     image_dir="pics",
#      10     answers=df['correct_answers'],
#      11     answers2=df['correct_answers_2'])
#
# Cell In[5], line 64, in test_vision(models_to_test, prompts, image_dir, answers, answers2)
#      62     continue
#      63 print(f"\nPrompt {i}/{len(prompts)} | Image: {image_path}")
# ---> 64 response = generate_response_ollama(
#      65     prompt=prompt,
#      66     image_path=image_path,
#      67     model=model_name
#      68 )
#      69 result_prompts.loc[i-1, model_name] = response
#      71 correct = check_answer(response, answers[i-1])
#
# Cell In[5], line 11, in generate_response_ollama(prompt, image_path, model, temperature)
#       9     image_bytes = f.read()
#      10 print(prompt)
# ---> 11 response = chat(
#      12     model=model,
#      13     messages=[{
#      14         "role": "user",
#      15         "content": prompt,
#      16         "images": [image_bytes]
#      17     }],
#      18     options={
#      19         "temperature": temperature
#      20     }
#      21 )
#      23 return response.message.content or ""
#
# File d:\anaconda\envs\MLenv\lib\site-packages\ollama\_client.py:365, in Client.chat(self, model, messages, tools, stream, think, logprobs, top_logprobs, format, options, keep_alive)
#     318 def chat(
#     319   self,
#     320   model: str = '',
#    (...)
#     330   keep_alive: Optional[Union[float, str]] = None,
#     331 ) -> Union[ChatResponse, Iterator[ChatResponse]]:
#     332   """
#     333   Create a chat response using the requested model.
#     334
#    (...)
#     363   Returns `ChatResponse` if `stream` is `False`, otherwise returns a `ChatResponse` generator.
#     364   """
# --> 365   return self._request(
#     366     ChatResponse,
#     367     'POST',
#     368     '/api/chat',
#     369     json=ChatRequest(
#     370       model=model,
#     371       messages=list(_copy_messages(messages)),
#     372       tools=list(_copy_tools(tools)),
#     373       stream=stream,
#     374       think=think,
#     375       logprobs=logprobs,
#     376       top_logprobs=top_logprobs,
#     377       format=format,
#     378       options=options,
#     379       keep_alive=keep_alive,
#     380     ).model_dump(exclude_none=True),
#     381     stream=stream,
#     382   )
#
# File d:\anaconda\envs\MLenv\lib\site-packages\ollama\_client.py:189, in Client._request(self, cls, stream, *args, **kwargs)
#     185         yield cls(**part)
#     187   return inner()
# --> 189 return cls(**self._request_raw(*args, **kwargs).json())
#
# File d:\anaconda\envs\MLenv\lib\site-packages\ollama\_client.py:133, in Client._request_raw(self, *args, **kwargs)
#     131   return r
#     132 except httpx.HTTPStatusError as e:
# --> 133   raise ResponseError(e.response.text, e.response.status_code) from None
#     134 except httpx.ConnectError:
#     135   raise ConnectionError(CONNECTION_ERROR_MESSAGE) from None
#
# ResponseError: model requires more system memory (8.2 GiB) than is available (5.7 GiB) (status code: 500)

# %%
response.choices[0].message
# Out:
# ChatCompletionOutputMessage(role='assistant', content='\nLeść komentarzeznawstwo Przetestuj Tiktaka w Kalkulatorze podobieństwa tekstów! [istnieje ją Marynarczyk]: Sztuczna inteligencja - rozbiór, co to jest? Nagrywanie wideo kamerą z derektorem z GoPro militaria tableta Ulepszenie inteligencji sztucznej z wykorzystaniem AR Niech schraniafik sztucznej inteligencji - monter, nauka | Touch Draw 3D! Jaka jest sztuczna inteligencja, jaka odmiana sztucznej inteligencji, jaka sztuczna inteligencja, co to jest sztuczna inteligencja i w jaki sposób działa sztuczna', reasoning=None, tool_call_id=None, tool_calls=None)
